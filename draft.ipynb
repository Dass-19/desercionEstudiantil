# %%
import pandas as pd

# %%
input_data = pd.DataFrame({'PROM_PERIODO': 1, 'ASIST_PROM': 2, 'TOTAL_MAT': 3, 'REPROBADAS': 4,
            'REPITENCIAS': 5,
            'NIVEL': 6
        }, index=[x for x in range(0, 6)])

# %%
int(input_data['PROM_PERIODO'][0])
# Out:
# 1
